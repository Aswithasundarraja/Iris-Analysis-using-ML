# %%
import pandas as pd
a=pd.read_csv("drive/MyDrive/iris23.csv")
print(a)
# Out:
#       q1   q2  setosa  versicolor  virginica
# 0    5.1  3.5     1.4         0.2          0
# 1    4.9  3.0     1.4         0.2          0
# 2    4.7  3.2     1.3         0.2          0
# 3    4.6  3.1     1.5         0.2          0
# 4    5.0  3.6     1.4         0.2          0
# ..   ...  ...     ...         ...        ...
# 145  6.7  3.0     5.2         2.3          2
# 146  6.3  2.5     5.0         1.9          2
# 147  6.5  3.0     5.2         2.0          2
# 148  6.2  3.4     5.4         2.3          2
# 149  5.9  3.0     5.1         1.8          2
#
# [150 rows x 5 columns]

# %%
a.isna().sum()
# Out:
# q1            0
# q2            0
# setosa        0
# versicolor    0
# virginica     0
# dtype: int64

# %%
from matplotlib import pyplot as plt
plt.scatter(a["q1"],a["virginica"])

# %%
plt.plot(a["q2"],a["virginica"])

# %%
plt.bar(a["setosa"],a["virginica"])
# Out:
# <BarContainer object of 150 artists>

# %%
x=a.iloc[:,:-1]
y=a["virginica"]
print(x)
# Out:
#       q1   q2  setosa  versicolor
# 0    5.1  3.5     1.4         0.2
# 1    4.9  3.0     1.4         0.2
# 2    4.7  3.2     1.3         0.2
# 3    4.6  3.1     1.5         0.2
# 4    5.0  3.6     1.4         0.2
# ..   ...  ...     ...         ...
# 145  6.7  3.0     5.2         2.3
# 146  6.3  2.5     5.0         1.9
# 147  6.5  3.0     5.2         2.0
# 148  6.2  3.4     5.4         2.3
# 149  5.9  3.0     5.1         1.8
#
# [150 rows x 4 columns]

# %%
print(y)
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 145    2
# 146    2
# 147    2
# 148    2
# 149    2
# Name: virginica, Length: 150, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
print(x_train)
# Out:
#       q1   q2  setosa  versicolor
# 40   5.0  3.5     1.3         0.3
# 39   5.1  3.4     1.5         0.2
# 5    5.4  3.9     1.7         0.4
# 74   6.4  2.9     4.3         1.3
# 125  7.2  3.2     6.0         1.8
# ..   ...  ...     ...         ...
# 57   4.9  2.4     3.3         1.0
# 42   4.4  3.2     1.3         0.2
# 41   4.5  2.3     1.3         0.3
# 49   5.0  3.3     1.4         0.2
# 142  5.8  2.7     5.1         1.9
#
# [120 rows x 4 columns]

# %%
print(x_test)
# Out:
#       q1   q2  setosa  versicolor
# 115  6.4  3.2     5.3         2.3
# 28   5.2  3.4     1.4         0.2
# 149  5.9  3.0     5.1         1.8
# 110  6.5  3.2     5.1         2.0
# 46   5.1  3.8     1.6         0.2
# 15   5.7  4.4     1.5         0.4
# 102  7.1  3.0     5.9         2.1
# 144  6.7  3.3     5.7         2.5
# 134  6.1  2.6     5.6         1.4
# 13   4.3  3.0     1.1         0.1
# 27   5.2  3.5     1.5         0.2
# 1    4.9  3.0     1.4         0.2
# 82   5.8  2.7     3.9         1.2
# 99   5.7  2.8     4.1         1.3
# 56   6.3  3.3     4.7         1.6
# 143  6.8  3.2     5.9         2.3
# 124  6.7  3.3     5.7         2.1
# 119  6.0  2.2     5.0         1.5
# 135  7.7  3.0     6.1         2.3
# 47   4.6  3.2     1.4         0.2
# 112  6.8  3.0     5.5         2.1
# 45   4.8  3.0     1.4         0.3
# 107  7.3  2.9     6.3         1.8
# 137  6.4  3.1     5.5         1.8
# 67   5.8  2.7     4.1         1.0
# 64   5.6  2.9     3.6         1.3
# 95   5.7  3.0     4.2         1.2
# 60   5.0  2.0     3.5         1.0
# 94   5.6  2.7     4.2         1.3
# 7    5.0  3.4     1.5         0.2

# %%
print(y_train)
# Out:
# 40     0
# 39     0
# 5      0
# 74     1
# 125    2
#       ..
# 57     1
# 42     0
# 41     0
# 49     0
# 142    2
# Name: virginica, Length: 120, dtype: int64

# %%
print(y_test)
# Out:
# 115    2
# 28     0
# 149    2
# 110    2
# 46     0
# 15     0
# 102    2
# 144    2
# 134    2
# 13     0
# 27     0
# 1      0
# 82     1
# 99     1
# 56     1
# 143    2
# 124    2
# 119    2
# 135    2
# 47     0
# 112    2
# 45     0
# 107    2
# 137    2
# 67     1
# 64     1
# 95     1
# 60     1
# 94     1
# 7      0
# Name: virginica, dtype: int64

# %%
from sklearn.linear_model import LogisticRegression
b=LogisticRegression()
b.fit(x_train,y_train)
y_pred=b.predict(x_test)
from sklearn.metrics import accuracy_score
print(accuracy_score(y_test,y_pred))
# Out:
# 0.9666666666666667
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
from sklearn.metrics import confusion_matrix
print(confusion_matrix(y_test,y_pred))
# Out:
# [[ 9  0  0]
#  [ 0  8  0]
#  [ 0  1 12]]

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         9
#            1       0.89      1.00      0.94         8
#            2       1.00      0.92      0.96        13
#
#     accuracy                           0.97        30
#    macro avg       0.96      0.97      0.97        30
# weighted avg       0.97      0.97      0.97        30
